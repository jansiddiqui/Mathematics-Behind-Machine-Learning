# %% [markdown]
# <a href="https://colab.research.google.com/github/jansiddiqui/Mathematics-Behind-Machine-Learning/blob/main/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# System Specification

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0xffffffff
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa mmio_stale_data retbleed bhi
# ...

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13289424 kB
# MemFree:         7978840 kB
# MemAvailable:   12265276 kB
# Buffers:          395252 kB
# Cached:          4064596 kB
# SwapCached:            0 kB
# Active:           710400 kB
# Inactive:        4315524 kB
# Active(anon):       1276 kB
# Inactive(anon):   566576 kB
# Active(file):     709124 kB
# Inactive(file):  3748948 kB
# Unevictable:           8 kB
# Mlocked:               8 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               216 kB
# Writeback:             0 kB
# AnonPages:        566092 kB
# Mapped:           318660 kB
# Shmem:              1768 kB
# KReclaimable:     138608 kB
# Slab:             178000 kB
# SReclaimable:     138608 kB
# SUnreclaim:        39392 kB
# KernelStack:        5396 kB
# PageTables:        10476 kB
# SecPageTables:         0 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6644712 kB
# Committed_AS:    2630424 kB
# ...

# %% [markdown]
# Installing Libraries

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/student_lifestyle_dataset..csv')

# %%
df.head()
# Out:
#    Student_ID  Study_Hours_Per_Day  Extracurricular_Hours_Per_Day  \
# 0           1                  6.9                            3.8
# 1           2                  5.3                            3.5
# 2           3                  5.1                            3.9
# 3           4                  6.5                            2.1
# 4           5                  8.1                            0.6
#
#    Sleep_Hours_Per_Day  Social_Hours_Per_Day  Physical_Activity_Hours_Per_Day  \
# 0                  8.7                   2.8                              1.8
# 1                  8.0                   4.2                              3.0
# 2                  9.2                   1.2                              4.6
# 3                  7.2                   1.7                              6.5
# 4                  6.5                   2.2                              6.6
#
#   Stress_Level  Gender  Grades
# 0     Moderate    Male    7.48
# 1          Low  Female    6.88
# ...

# %%
# !ls
# Out:
# sample_data  student_lifestyle_dataset..csv
